# %%
import extract, index, prepare

# %%
filenames, errors = prepare.files_to_plain_text("papers_example", recursive=True)
# Out:
# Current path location:
# 	c:\Users\Lenovo\Documents\git\RAG-exeperiment\rag_experiment
# Detected file preamble.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# Detected file 1_intro.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# Detected file 2_types.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# Detected file 3_llm.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# Detected file 4_factoid.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# Detected file 5_fe.tex:
# 	File not found in ./
# 	File not found in ../
# 	File not found in papers_example/
# 	File not found in __pycache__/
# ...

# %%
filenames
# Out:
# ['papers_example\\2403.18350v1.Evaluation_of_Semantic_Search_and_its_Role_in_Retrieved_Augmented_Generation__RAG__for_Arabic_Language.tar\\templateArxiv.tex.txt',
#  'papers_example\\2403.18350v1.Evaluation_of_Semantic_Search_and_its_Role_in_Retrieved_Augmented_Generation__RAG__for_Arabic_Language.tar\\templatePRIME.tex.txt',
#  'papers_example\\2403.18920v1.CPR__Retrieval_Augmented_Generation_for_Copyright_Protection.tar\\main.tex.txt',
#  'papers_example\\2403.18920v1.CPR__Retrieval_Augmented_Generation_for_Copyright_Protection.tar\\preamble.tex.txt',
#  'papers_example\\2403.18920v1.CPR__Retrieval_Augmented_Generation_for_Copyright_Protection.tar\\supp_matt.tex.txt',
#  'papers_example\\2403.19113v1.FACTOID__FACtual_enTailment_fOr_hallucInation_Detection.tar\\0_main.tex.txt',
#  'papers_example\\2403.19113v1.FACTOID__FACtual_enTailment_fOr_hallucInation_Detection.tar\\10_faq.tex.txt',
# ...

# %%
with open('out.txt', 'w') as f:
    for line in filenames:
        f.write(f"{line}\n")

# %%
# %pip install sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/171.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/171.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/171.5 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/171.5 kB 326.8 kB/s eta 0:00:01
#    ----------- --------------------------- 51.2/171.5 kB 290.5 kB/s eta 0:00:01
#    ------------------ -------------------- 81.9/171.5 kB 381.3 kB/s eta 0:00:01
#    ----------------------------- -------- 133.1/171.5 kB 525.1 kB/s eta 0:00:01
#    ------------------------------------ - 163.8/171.5 kB 577.4 kB/s eta 0:00:01
#    -------------------------------------- 171.5/171.5 kB 542.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
db = index.open_db()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\Lenovo\Documents\git\RAG-exeperiment\.venv\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
docs = []
for filename in filenames:
    with open(filename) as f:
        text = f.read()
        docs.extend(prepare.split_to_sentences(text))

# %%
index.populate_and_prepare_db('default', docs)
# Out:
# c:\Users\Lenovo\Documents\git\RAG-exeperiment\.venv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Indexing 1235 documents
#   0%|          | 0/1235 [00:00<?, ?it/s]Created a chunk of size 824, which is longer than the specified 500
# Created a chunk of size 673, which is longer than the specified 500
# Created a chunk of size 782, which is longer than the specified 500
# Created a chunk of size 887, which is longer than the specified 500
#   0%|          | 1/1235 [00:04<1:28:02,  4.28s/it]Created a chunk of size 554, which is longer than the specified 500
# Created a chunk of size 589, which is longer than the specified 500
# Created a chunk of size 619, which is longer than the specified 500
# ...

# %%
index.search_for_documents("default","rag")
# Out:
# []
